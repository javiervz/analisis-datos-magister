# %%
## algunos ejercicios con pandas y Glottolog :)

import pandas as pd

# %%
## https://glottolog.org/meta/downloads

languoids = pd.read_csv('languoid.csv',sep=',')

# %%
languoids
# Out:
#              id family_id parent_id                 name  bookkeeping  \
# 0      3adt1234  afro1255  nort3292           3Ad-Tekles        False
# 1      aala1237  aust1307  ramo1244               Aalawa        False
# 2      aant1238  nucl1709  nort2920           Aantantara        False
# 3      aari1238  sout2845  ahkk1235           Aari-Gayil        False
# 4      aari1239  sout2845  aari1238                 Aari        False
# ...         ...       ...       ...                  ...          ...
# 25434  zuti1239  tupi1275  guaj1255  Guajajára of Zutiua        False
# 25435  zuwa1238  koia1260  omie1241              Zuwadza        False
# 25436  zwal1238  atla1278  shal1242                Zwall        False
# 25437  zyph1238  sino1245  nucl1757                Zyphe        False
# 25438  zyud1238  ural1272  komi1269              Zyuzdin        False
#
#           level  latitude  longitude iso639P3code  description  \
# ...

# %% [markdown]
# Para comenzar filtre **languoids**, es decir pode filas innecesarias, usando solamente lenguas de sudamérica. Una forma es usar datos analizados en la clase 4 :) Recuerde qué almacena el diccionario **macroarea**. Recomendación: guárdelo en pickle y lealo acá :)

# %% [markdown]
# Construya un diccionario **glottocode:family_id**

# %% [markdown]
# Construya un diccionario **iso:family_id**

# %% [markdown]
# Construya un diccionario **family_id:lista de códigos glottocode pertenecientes a family_id**. Filtrar el diccionario por lenguas de América del Sur. Guardar el diccionario como pickle.

# %% [markdown]
# Use el diccionario anterior para calcular el **número de familias que tienen un número X de lenguas**

# %% [markdown]
# **Grafique en dos dimensiones** la información anterior :)

# %% [markdown]
# ¿Cuántas lenguas posee la familia **quec1387?** Use **languoid[languoid['family_id']='quec1387']**

# %% [markdown]
# Use las columnas **latitude y longitude** para crear un gráfico que ubique cada lengua en un plano de dos dimensiones
